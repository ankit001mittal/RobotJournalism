# %%
import requests
import xml.etree.ElementTree as ET

# %%
r =requests.get('https://ankit:sfsznojlczeyxclp@ori-ndc-archief.gw20e.com/oa?value=sports&verb=list&first=1&last=14&content=body')

# %%
type(r.content)
# Out:
# bytes

# %%
string_xml = r.text
tree = ET.fromstring(string_xml)

ET.dump(tree)
# Out:
# Traceback (most recent call last):
#
#   File "/Users/ankitmittal/Library/Python/3.7/lib/python/site-packages/IPython/core/interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-30-db3a27bd6521>", line 2, in <module>
#     tree = ET.fromstring(string_xml)
#
#   File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/xml/etree/ElementTree.py", line 1315, in XML
#     parser.feed(text)
#
#   File "<string>", line unknown
# ParseError: not well-formed (invalid token): line 12, column 591

# %%
import requests
import xml.etree.ElementTree as ET

r = requests.get('https://ankit:sfsznojlczeyxclp@ori-ndc-archief.gw20e.com/oa?value=vindicat&verb=list&first=0&last=14&content=body')
tree = ET.parse(r.text)
root = tree.getroot()

root = ET.fromstring(r.content)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-19-9c1bc734ae55> in <module>
#       3
#       4 r = requests.get('https://ankit:sfsznojlczeyxclp@ori-ndc-archief.gw20e.com/oa?value=vindicat&verb=list&first=0&last=14&content=body')
# ----> 5 tree = ET.parse(r.text)
#       6 root = tree.getroot()
#       7
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/xml/etree/ElementTree.py in parse(source, parser)
#    1195     """
#    1196     tree = ElementTree()
# -> 1197     tree.parse(source, parser)
#    1198     return tree
#    1199
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/xml/etree/ElementTree.py in parse(self, source, parser)
#     585         close_source = False
#     586         if not hasattr(source, "read"):
# ...
